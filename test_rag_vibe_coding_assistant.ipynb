# %% [markdown]
# ##🔥 Vibe Coding AI представляет: ЛИЧНЫЙ RAG-АССИСТЕНТ 🔥
#
# Используем Colab для доступа к Google Drive и Telegram-бота на aiogram 3.x

# %% [markdown]
# My tokens (Alex)

# %%
hf = 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

# %% [markdown]
# ## 🧠 Инструкция по запуску RAG-ассистента от Vibe Coding AI
#
# Добро пожаловать в адскую машину знаний от Vibe Coding.
# Сейчас быстро разрулим, как всё запустить и не словить дебаг в мозг.
#
# Просто следуй по шагам — и будет тебе ламповый RAG-вайб.
#
# ---
#
# ### 🚀 Шаг 1: Вставь свои ключи
#
# В самой первой секции укажи:
#
# - `OPENAI_API_KEY` — ключ от OpenAI (можно взять на [platform.openai.com](https://platform.openai.com))
# - `HF_TOKEN` — токен от HuggingFace (если не знаешь, гугли "huggingface token")
# - `TELEGRAM_TOKEN` — если хочешь подключить Telegram-бота
#
# Без этого ассистент будет просто куклой без души.
#
# ---
#
# ### 📁 Шаг 2: Укажи путь к документам
#
# Задай путь к папке на Google Drive, где лежат твои файлы:
# `.pdf`, `.txt`, `.docx` — это наш хлеб. Остальное в печь.
#
# Путь задаётся в параметре `DOCS_FOLDER_PATH`.
#
# ---
#
# ### ⚙️ Шаг 3: Настрой производительность (не обязательно, но заебись)
#
# В этой секции можно:
#
# - ✅ Включить `USE_GPU` — чтобы эмбеддинги летали, как Falcon 9
#
# Не забудь в Colab включить GPU: `Среда выполнения > Сменить среду выполнения > GPU`.
# - 🔪 Установить `CHUNK_SIZE` — размер куска текста (по дефолту 1500 — норм)
#
# Чем больше, тем меньше чанков, но выше риск потери контекста.
# - 🩹 Настроить `CHUNK_OVERLAP` — перекрытие между чанками (рекомендуем 300)
#
# Добавь немного (100–300), чтобы куски цеплялись друг за друга и не теряли смысл.
#
# Если хз, что это — **не трогай**. По умолчанию всё заебись работает.
#
# ---
#
# ### 🧠 Шаг 4: Загрузи документы ИЛИ подгрузи базу
#
# **Первый запуск?** Жми на:
#
# ```python
# await load_docs_from_drive()
# ```
#
# Он загрузит документы, нарежет их, векторизует и сохранит базу.
#
# **Уже есть база?** Тогда просто:
#
# ```python
# await load_vectorstore()
# ```
#
# И всё — можешь сразу работать, как будто ничего не случилось.
#
# ---
#
# ### 🔍 Шаг 5: Протестируй RAG
#
# Проверь, как ассистент отвечает:
#
# ```python
# question = input("⚡ Введи вопрос к базе знаний: ")
# await test_query(question)
# ```
#
# Если он не отвечает или тупит — значит, ты где-то налажал на прошлом шаге 😤
#
# ---
#
# ### 🤖 Шаг 6: Хочешь Telegram-бота? Получи!
#
# Если ты включал `TELEGRAM_TOKEN`, можешь запустить бота и общаться с ассистентом прямо в Telegram.
#
# Команды:
# - `/start` — запустить
# - `/status` — глянуть, загружено ли всё
# - `/help` — ну ты понял
#
# ---
#
# ### 🎯 Готово!
#
# Если дошёл до сюда — ты красава.
# Теперь можешь кайфовать от кода, знаний и вайба, как будто ты Карпатыч на спидах.
#
# 🔥 Кодь на вайбе. Вопросы задавай дерзко. Ответы будут с огоньком. Vibe Coding — или нахуй с пляжа!

# %%
# @title УСТАНОВКА НЕОБХОДИМЫХ БИБЛИОТЕК:
# !pip install langchain langchain-community langchain-openai
# !pip install sentence-transformers faiss-cpu python-dotenv
# !pip install pydantic pymupdf aiogram
# !pip install unstructured[pdf,docx,txt]
# !pip install -U langchain-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.9/433.9 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.52
#     Uninstalling langchain-core-0.3.52:
#       Successfully uninstalled langchain-core-0.3.52
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.3 MB/s eta 0:00:00
# ...

# %%
# @title Импорты и настройка логирования

import os
import sys
import logging
import tempfile
from typing import List, Dict, Any
import asyncio
import time

# Импортируем Google Colab для доступа к Google Drive
try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False
    print("❌ Код запущен не в Google Colab. Некоторые функции могут не работать.")

# Импортируем компоненты LangChain для RAG-системы
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import PyMuPDFLoader, TextLoader, UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# Для телеграм-бота
from aiogram import Bot, Dispatcher, Router, F
from aiogram.types import Message, FSInputFile, CallbackQuery
from aiogram.filters import Command, CommandStart
from aiogram.fsm.context import FSMContext
from aiogram.fsm.state import State, StatesGroup
from aiogram.fsm.storage.memory import MemoryStorage
from aiogram.utils.formatting import Bold, Code, Text
from aiogram.enums import ParseMode
import aiogram.exceptions

# В Colab нужно использовать следующий хелпер для запуска асинхронных функций
import nest_asyncio
nest_asyncio.apply()

# Настройка логирования
logging.basicConfig(
    format='%(asctime)s - VIBE CODING: %(levelname)s - %(message)s',
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# %%
# СЕКЦИЯ ДЛЯ COLAB SECRETS - ХРАНИМ ЗДЕСЬ КЛЮЧИ API
# @title 🔑 Настройка API-ключей
# @markdown Введите ваши ключи API для доступа к сервисам:

# @markdown ---
# @markdown ### OpenAI API
OPENAI_API_KEY = "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" # @param {type:"string"}

# @markdown ### Telegram Bot
TELEGRAM_TOKEN = "ewq" # @param {type:"string"}

# @markdown ### HuggingFace
HF_TOKEN = "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" # @param {type:"string"}

# Проверка наличия необходимых токенов
if not OPENAI_API_KEY or OPENAI_API_KEY.startswith("sk-..."):
    logger.error("БЛЯТЬ! OPENAI_API_KEY отсутствует! Как мы будем генерировать ответы?!")
    # В Colab сделаем красивый вывод
    from IPython.display import HTML, display
    display(HTML("""
    <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
        <h3 style="margin-top:0">⚠️ Ошибка! API ключ OpenAI отсутствует!</h3>
        <p>Пожалуйста, добавьте свой OpenAI API ключ в секцию выше.</p>
    </div>
    """))

if not TELEGRAM_TOKEN or TELEGRAM_TOKEN == "...":
    logger.error("НАХУЙ! TELEGRAM_TOKEN отсутствует! Какой бот без токена?!")
    # В Colab сделаем красивый вывод
    from IPython.display import HTML, display
    display(HTML("""
    <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
        <h3 style="margin-top:0">⚠️ Ошибка! Токен Telegram бота отсутствует!</h3>
        <p>Пожалуйста, добавьте токен вашего Telegram бота в секцию выше.</p>
    </div>
    """))

if not HF_TOKEN or HF_TOKEN == "hf_":
    logger.error("HF_TOKEN отсутствует! Пиздуй за токеном!")
    # В Colab сделаем красивый вывод
    from IPython.display import HTML, display
    display(HTML("""
    <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
        <h3 style="margin-top:0">⚠️ Ошибка! Токен Hugging Face отсутствует!</h3>
        <p>Пожалуйста, добавьте ваш токен Hugging Face в секцию выше.</p>
    </div>
    """))

# %%
# @title 📂 Настройка пути к документам на Google Drive
# @markdown Укажите путь к вашей папке с документами на Google Drive:

DOCS_FOLDER_PATH = "/content/drive/MyDrive/rag_test_folder" # @param {type:"string"}
VECTORSTORE_PATH = "/content/drive/MyDrive/rag_test_folder" # @param {type:"string"}

# Монтируем Google Drive, если мы в Colab
if IN_COLAB:
    try:
        drive.mount('/content/drive')
        logger.info("✅ Google Drive подключен успешно!")
    except Exception as e:
        logger.error(f"❌ Ошибка при подключении Google Drive: {str(e)}")
        # В Colab сделаем красивый вывод
        from IPython.display import HTML, display
        display(HTML("""
        <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
            <h3 style="margin-top:0">⚠️ Ошибка! Не удалось подключить Google Drive!</h3>
            <p>Пожалуйста, подключите Google Drive вручную.</p>
        </div>
        """))
# Out:
# Mounted at /content/drive

# %%
# @title 🧠 Настройка GPU и производительности
# @markdown Включите или отключите использование GPU:

USE_GPU = True # @param {type:"boolean"}
CHUNK_SIZE = 1500 # @param {type:"slider", min:500, max:2000, step:100}
CHUNK_OVERLAP = 300 # @param {type:"slider", min:0, max:500, step:50}

# %%
# @title Определение состояний для FSM
class UserStates(StatesGroup):
    waiting_for_document = State()
    waiting_for_query = State()
    waiting_for_folder_path = State()

# %%
# @title Класс для нашей RAG-системы
class RAGSystem:
    def __init__(self, openai_api_key=None):
        # Проверяем наличие GPU и настройки пользователя
        device = "cpu"
        if USE_GPU:
            try:
                import torch
                device = "cuda" if torch.cuda.is_available() else "cpu"
                if device == "cuda":
                    logger.info("🚀 НАХУЙ! У НАС ЕСТЬ GPU! Будем юзать его для эмбеддингов!")
                else:
                    logger.info("😢 GPU не обнаружен, используем CPU. Будет медленнее...")
            except:
                logger.info("PyTorch не найден или ошибка при проверке GPU. Используем CPU.")
        else:
            logger.info("🔄 Использование GPU отключено в настройках. Используем CPU.")

        # Инициализация эмбеддингов с выбранной моделью
        logger.info(f"🧠 Инициализация эмбеддингов E5-large на {device.upper()}...")
        self.embeddings = HuggingFaceEmbeddings(
            model_name="intfloat/e5-large",  # Топовая модель!
            model_kwargs={
                'device': device,
                'token': HF_TOKEN
            },
            encode_kwargs={'normalize_embeddings': True}
        )

        # Инициализация LLM
        logger.info("🤖 Инициализация языковой модели OpenAI...")
        self.llm = ChatOpenAI(
            model_name="gpt-4o-mini",
            temperature=0.7,
            api_key=openai_api_key or OPENAI_API_KEY
        )

        # Хранилище документов
        self.vectorstore = None

        # Флаг загрузки документов
        self.is_loaded = False

        # Создание сплиттера для документов
        logger.info(f"✂️ Настройка разделителя документов (размер чанка: {CHUNK_SIZE}, перекрытие: {CHUNK_OVERLAP})...")
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=CHUNK_SIZE,
            chunk_overlap=CHUNK_OVERLAP,
            length_function=len,
            separators=["\n\n", "\n", " ", ""]
        )

        # Создание шаблона промпта для запросов
        self.prompt_template = """
        Ты — дерзкий ассистент из телеграм-канала Vibe Coding AI, который отвечает на вопросы по книге "Грокаем алгоритмы".
        Даже если в контексте кажется, что нет прямого ответа на вопрос, попробуй найти связанную информацию и дать полезный ответ.
        Используй свои знания об алгоритмах, если информации недостаточно.

        Контекст из книги:
        {context}

        Вопрос пользователя: {question}

        Если в контексте действительно совсем нет информации по вопросу, только тогда скажи
        "Блять, в документах нет инфы по этому вопросу. Загрузи что-то получше или спроси что-то другое."

        Твой стиль - дерзкий, с программистским сленгом. Отвечай ярко и энергично.

        Ответ:
        """

        self.PROMPT = PromptTemplate(
            template=self.prompt_template,
            input_variables=["context", "question"]
        )

    async def load_document(self, file_path: str) -> List[Document]:
        """Загрузка документа из файла"""
        logger.info(f"📄 Загрузка документа: {file_path}")

        try:
            if file_path.lower().endswith('.pdf'):
                loader = PyMuPDFLoader(file_path)
            elif file_path.lower().endswith('.txt'):
                loader = TextLoader(file_path)
            elif file_path.lower().endswith('.docx'):
                loader = UnstructuredFileLoader(file_path)
            else:
                raise ValueError(f"Неподдерживаемый формат файла: {file_path}")

            # Выполняем загрузку в отдельном потоке
            documents = await asyncio.to_thread(lambda: loader.load())

            logger.info(f"✅ Загружено {len(documents)} страниц/частей из {file_path}")
            return documents
        except Exception as e:
            logger.error(f"❌ Ошибка при загрузке документа {file_path}: {str(e)}")
            return []

    async def process_documents(self, documents: List[Document]) -> None:
        """Обработка и создание векторного хранилища из документов"""
        if not documents:
            logger.error("❌ Нет документов для обработки!")
            return

        logger.info("✂️ Разделение документов на чанки...")

        # Выполняем разделение в отдельном потоке
        chunks = await asyncio.to_thread(self.text_splitter.split_documents, documents)
        logger.info(f"✅ Создано {len(chunks)} чанков")

        logger.info("🧠 Создание векторного хранилища...")

        # Создаем векторное хранилище в отдельном потоке
        if self.vectorstore is None:
            self.vectorstore = await asyncio.to_thread(FAISS.from_documents, chunks, self.embeddings)
        else:
            # Добавляем новые документы к существующему хранилищу
            await asyncio.to_thread(lambda: self.vectorstore.add_documents(chunks))

        logger.info("✅ Векторное хранилище создано")
        self.is_loaded = True

    async def save_vectorstore(self, directory: str = VECTORSTORE_PATH) -> None:
        """Сохранение векторного хранилища на диск"""
        if not self.is_loaded:
            logger.warning("⚠️ Нет загруженных документов для сохранения!")
            return

        # Создаем директорию, если она не существует
        os.makedirs(directory, exist_ok=True)

        await asyncio.to_thread(self.vectorstore.save_local, directory)
        logger.info(f"💾 Векторное хранилище сохранено в {directory}")

    async def load_vectorstore(self, directory: str = VECTORSTORE_PATH, allow_dangerous_deserialization: bool = False) -> None:
        """Загрузка векторного хранилища с диска"""
        if not os.path.exists(directory):
            logger.warning(f"⚠️ Директория {directory} не существует!")
            return

        # Исправленная версия с поддержкой параметра allow_dangerous_deserialization
        self.vectorstore = await asyncio.to_thread(
            lambda: FAISS.load_local(
                directory,
                self.embeddings,
                allow_dangerous_deserialization=allow_dangerous_deserialization
            )
        )
        logger.info(f"📂 Векторное хранилище загружено из {directory}")
        self.is_loaded = True

    async def load_documents_from_drive(self, folder_path: str) -> List[str]:
        """Загрузка документов из указанной папки на Google Drive"""
        if not IN_COLAB and not os.path.exists(folder_path):
            logger.error(f"❌ Папка не найдена: {folder_path}")
            return []

        logger.info(f"🔍 Поиск документов в папке {folder_path}...")

        # Получаем список файлов в папке
        try:
            files = []
            supported_extensions = ['.pdf', '.txt', '.docx']

            # Рекурсивный обход директорий
            for root, _, filenames in os.walk(folder_path):
                for filename in filenames:
                    ext = os.path.splitext(filename)[1].lower()
                    if ext in supported_extensions:
                        files.append({
                            'name': filename,
                            'path': os.path.join(root, filename)
                        })

            logger.info(f"📚 Найдено {len(files)} документов в папке {folder_path}")

            if not files:
                logger.warning("⚠️ В указанной папке нет поддерживаемых документов!")
                return []
        except Exception as e:
            logger.error(f"❌ Ошибка при поиске документов: {str(e)}")
            return []

        all_documents = []
        loaded_files = []

        # Загружаем каждый файл и обрабатываем его
        for file in files:
            try:
                logger.info(f"⏬ Загрузка файла {file['name']}...")

                # Загружаем документ
                documents = await self.load_document(file['path'])

                if not documents:
                    continue

                all_documents.extend(documents)

                # Добавляем имя файла в список загруженных
                loaded_files.append(file['name'])

            except Exception as e:
                logger.error(f"❌ Ошибка при обработке файла {file['name']}: {str(e)}")

        # Обрабатываем все загруженные документы
        if all_documents:
            logger.info(f"🧩 Обработка {len(all_documents)} документов...")
            await self.process_documents(all_documents)
            return loaded_files
        else:
            logger.warning("⚠️ Не удалось загрузить ни одного документа!")
            return []

    async def query(self, question: str) -> str:
        """Запрос к системе"""
        if not self.is_loaded:
            return "⚠️ Сначала загрузи документы! Какого хуя я должен отвечать на пустоту?!"

        try:
            start_time = time.time()

            # Получаем релевантные чанки
            retriever = self.vectorstore.as_retriever(search_kwargs={"k": 10})

            # Создаем цепочку для ответа на вопрос
            qa_chain = RetrievalQA.from_chain_type(
                llm=self.llm,
                chain_type="stuff",
                retriever=retriever,
                return_source_documents=True,
                chain_type_kwargs={"prompt": self.PROMPT}
            )

            # Выполняем запрос в отдельном потоке
            result = await asyncio.to_thread(lambda: qa_chain({"query": question}))

            # Форматируем ответ с источниками
            answer = result["result"]
            sources = set()

            # Добавляем список источников
            for doc in result["source_documents"]:
                if hasattr(doc, 'metadata') and 'source' in doc.metadata:
                    source_path = doc.metadata['source']
                    source_name = os.path.basename(source_path)
                    sources.add(source_name)

            elapsed_time = time.time() - start_time
            formatted_answer = f"{answer}\n\n"

            if sources:
                formatted_answer += f"📚 Источники: {', '.join(sources)}\n"

            formatted_answer += f"⏱️ Время ответа: {elapsed_time:.2f} сек"

            return formatted_answer

        except Exception as e:
            logger.error(f"❌ Ошибка при выполнении запроса: {str(e)}")
            return f"Произошла ошибка при обработке запроса: {str(e)}"

# %%
# @title 📊 Мониторинг производительности GPU
# @markdown Проверьте использование GPU перед запуском системы:

def check_gpu():
    """Проверка наличия и состояния GPU"""
    try:
        import torch
        if torch.cuda.is_available():
            gpu_info = {
                "Доступен": "Да",
                "Название": torch.cuda.get_device_name(0),
                "Память всего (GB)": round(torch.cuda.get_device_properties(0).total_memory / (1024**3), 2),
                "Память доступно (GB)": round(torch.cuda.memory_reserved(0) / (1024**3), 2)
            }

            if IN_COLAB:
                from IPython.display import HTML, display

                # Создаем таблицу для отображения
                table_html = "<table style='width:100%; border-collapse:collapse; margin-top:10px;'>"
                table_html += "<tr style='background-color:#4CAF50; color:white;'><th style='padding:8px; text-align:left;'>Параметр</th><th style='padding:8px; text-align:left;'>Значение</th></tr>"

                for i, (key, value) in enumerate(gpu_info.items()):
                    bg_color = "#f2f2f2" if i % 2 == 0 else "white"
                    table_html += f"<tr style='background-color:{bg_color};'><td style='padding:8px; border:1px solid #ddd;'>{key}</td><td style='padding:8px; border:1px solid #ddd;'>{value}</td></tr>"

                table_html += "</table>"

                display(HTML(f"""
                <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724; margin-bottom:20px">
                    <h3 style="margin-top:0">✅ GPU доступен!</h3>
                    {table_html}
                </div>
                """))
            else:
                print("✅ GPU доступен!")
                for key, value in gpu_info.items():
                    print(f"{key}: {value}")
        else:
            if IN_COLAB:
                from IPython.display import HTML, display
                display(HTML("""
                <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24; margin-bottom:20px">
                    <h3 style="margin-top:0">❌ GPU не доступен!</h3>
                    <p>Проверьте настройки среды выполнения Colab (Runtime > Change runtime type > Hardware accelerator > GPU)</p>
                </div>
                """))
            else:
                print("❌ GPU не доступен!")
    except Exception as e:
        if IN_COLAB:
            from IPython.display import HTML, display
            display(HTML(f"""
            <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24; margin-bottom:20px">
                <h3 style="margin-top:0">❌ Ошибка при проверке GPU!</h3>
                <p>Ошибка: {str(e)}</p>
            </div>
            """))
        else:
            print(f"❌ Ошибка при проверке GPU: {str(e)}")

# Запускаем проверку GPU
check_gpu()
# Out:
#                 <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724; margin-bottom:20px">
#                     <h3 style="margin-top:0">✅ GPU доступен!</h3>
# ...

# %%
# Демонстрация работы RAG-системы в Colab
# @title 🚀 Создание и тестирование RAG-системы
# @markdown Нажмите кнопку для создания RAG-системы:

if IN_COLAB:
    from IPython.display import HTML, display
    display(HTML("""
    <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724; margin-bottom:20px">
        <h3 style="margin-top:0">🚀 Создаем и тестируем RAG-систему</h3>
        <p>Сейчас мы загрузим документы с Google Drive и создадим базу знаний.</p>
    </div>
    """))

# Создаем глобальную RAG-систему
rag_system = RAGSystem()

# Функция для загрузки документов с Google Drive
async def load_docs_from_drive():
    """Загрузка документов с Google Drive"""
    loaded_files = await rag_system.load_documents_from_drive(DOCS_FOLDER_PATH)

    if loaded_files:
        # Сохраняем векторное хранилище
        await rag_system.save_vectorstore()

        if IN_COLAB:
            from IPython.display import HTML, display
            file_list = "".join([f"<li>{file}</li>" for file in loaded_files])
            display(HTML(f"""
            <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724">
                <h3 style="margin-top:0">✅ Успешно загружено {len(loaded_files)} документов!</h3>
                <p>Загруженные файлы:</p>
                <ul>{file_list}</ul>
            </div>
            """))
    else:
        if IN_COLAB:
            from IPython.display import HTML, display
            display(HTML("""
            <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
                <h3 style="margin-top:0">❌ Не удалось загрузить документы!</h3>
                <p>Проверьте путь к папке и наличие документов.</p>
            </div>
            """))

# Функция для загрузки векторного хранилища
async def load_vectorstore():
    """Загрузка векторного хранилища"""
    try:
        # Добавляем флаг для безопасной десериализации
        await rag_system.load_vectorstore(allow_dangerous_deserialization=True)

        if rag_system.is_loaded:
            if IN_COLAB:
                from IPython.display import HTML, display
                display(HTML("""
                <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724">
                    <h3 style="margin-top:0">✅ Векторное хранилище успешно загружено!</h3>
                    <p>Теперь можно задавать вопросы.</p>
                </div>
                """))
        else:
            if IN_COLAB:
                from IPython.display import HTML, display
                display(HTML("""
                <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
                    <h3 style="margin-top:0">❌ Не удалось загрузить векторное хранилище!</h3>
                    <p>Проверьте путь к хранилищу и наличие файлов.</p>
                </div>
                """))
    except Exception as e:
        if IN_COLAB:
            from IPython.display import HTML, display
            display(HTML(f"""
            <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
                <h3 style="margin-top:0">❌ Ошибка при загрузке векторного хранилища!</h3>
                <p>Ошибка: {str(e)}</p>
            </div>
            """))

async def test_query(question):
    """Тестирование запроса к RAG-системе"""
    if not rag_system.is_loaded:
        if IN_COLAB:
            from IPython.display import HTML, display
            display(HTML("""
            <div style="background-color:#FF4136; padding:20px; border-radius:10px; color:white; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
                <h3 style="margin-top:0; font-size:24px;">⛔️ СТОП, НАХРЕН!</h3>
                <p style="font-size:18px;">База знаний не загружена! Какого хрена ты пытаешься запросить?</p>
                <p style="font-size:16px; margin-top:10px;">👉 Сначала загрузи документы, потом поговорим!</p>
            </div>
            """))
        return

    answer = await rag_system.query(question)
    answer_html = answer.replace('\n', '<br>')

    if IN_COLAB:
        from IPython.display import HTML, display
        display(HTML(f"""
        <div style="background-color:#111; color:#fff; padding:25px; border-radius:15px; margin-top:20px; box-shadow: 0 6px 12px rgba(0,0,0,0.3); border-left: 5px solid #39CCCC;">
            <h3 style="margin-top:0; color:#FF851B; font-size:24px; text-transform:uppercase;">🔥 Вопрос:</h3>
            <p style="font-size:18px; background-color:#222; padding:15px; border-radius:8px;">{question}</p>

            <h3 style="color:#2ECC40; font-size:24px; margin-top:20px; text-transform:uppercase;">💥 Ответ:</h3>
            <div style="font-size:18px; background-color:#222; padding:15px; border-radius:8px; line-height:1.6;">{answer_html}</div>

            <div style="margin-top:15px; font-size:14px; color:#999; text-align:right;">Powered by Vibe Coding AI 🤘</div>
        </div>
        """))
    else:
        print("\n" + "=" * 50)
        print(f"🔥 ВОПРОС: {question}")
        print("=" * 50)
        print(f"💥 ОТВЕТ: {answer}")
        print("=" * 50 + "\n")
# Out:
#     <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724; margin-bottom:20px">
#         <h3 style="margin-top:0">🚀 Создаем и тестируем RAG-систему</h3>
#         <p>Сейчас мы загрузим документы с Google Drive и создадим базу знаний.</p>
#     </div>

# %%
# @title 🛠 Первый запуск: загружаем документы и создаём базу знаний
# ⬇️ Загрузка документов и создание базы
await load_docs_from_drive()
# Out:
#             <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724">
#                 <h3 style="margin-top:0">✅ Успешно загружено 3 документов!</h3>
#                 <p>Загруженные файлы:</p>
#                 <ul><li>my_favorite_food.txt</li><li>my_favorite_color.txt</li><li>my_favorite_animal.txt</li></ul>
#             </div>

# %%
# @title 🔁 Повторный запуск: если база уже есть
# 📂 Загрузка векторной базы из Google Drive
await load_vectorstore()
# Out:
#                 <div style="background-color:#d4edda; padding:20px; border-radius:5px; color:#155724">
#                     <h3 style="margin-top:0">✅ Векторное хранилище успешно загружено!</h3>
#                     <p>Теперь можно задавать вопросы.</p>
#                 </div>

# %%
# @title 🔍 Протестировать RAG — задаём вопрос
# 💥 Протестим ассистента
question = input("⚡ Введи вопрос к базе знаний: ")
await test_query(question)
# Out:
# What is my favorite food? What is my favorite food?
# <ipython-input-10-3dffc8e93bbb>:237: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = await asyncio.to_thread(lambda: qa_chain({"query": question}))
#         <div style="background-color:#111; color:#fff; padding:25px; border-radius:15px; margin-top:20px; box-shadow: 0 6px 12px rgba(0,0,0,0.3); border-left: 5px solid #39CCCC;">
#             <h3 style="margin-top:0; color:#FF851B; font-size:24px; text-transform:uppercase;">🔥 Вопрос:</h3>
#             <p style="font-size:18px; background-color:#222; padding:15px; border-radius:8px;">What is my favorite food?</p>
#
#             <h3 style="color:#2ECC40; font-size:24px; margin-top:20px; text-transform:uppercase;">💥 Ответ:</h3>
# ...

# %%
# @title Теперь интегрируем Telegram-бота для доступа к RAG-системе

# Инициализация бота
bot = Bot(token=TELEGRAM_TOKEN)
dp = Dispatcher(storage=MemoryStorage())
router = Router()

# Хранилище пользовательских данных
user_data: Dict[int, Dict[str, Any]] = {}

# Команда /start
@router.message(CommandStart())
async def cmd_start(message: Message):
    """Обработчик команды /start"""
    user_id = message.from_user.id

    # Инициализируем данные пользователя, если их нет
    if user_id not in user_data:
        user_data[user_id] = {
            "documents": []
        }

    # Проверяем, загружена ли глобальная RAG-система
    if not rag_system.is_loaded:
        await message.answer(
            "⚠️ RAG-система еще не загружена. Для начала работы с ботом необходимо "
            "загрузить документы в Colab-ноутбуке и запустить бота оттуда."
        )

    # Приветственное сообщение
    start_text = Text(
        "🔥 ", Bold("VIBE CODING AI"), " 🔥\n\n",
        "Привет! Я личный RAG-ассистент с ноутбуком в Google Colab.\n\n",
        "Что я могу:\n",
        "• Отвечать на вопросы по твоей базе знаний\n",
        "• Работать с документами, загруженными в Colab\n",
        "• Давать точные ответы на основе твоих документов\n\n",
        "Используй /help для подробной инструкции."
    )

    await message.answer(**start_text.as_kwargs())

# Команда /help
@router.message(Command("help"))
async def cmd_help(message: Message):
    """Обработчик команды /help"""
    help_text = Text(
        "🔥 ", Bold("ДОСТУПНЫЕ КОМАНДЫ"), " 🔥\n\n",
        "/start - начать работу с ботом\n",
        "/status - проверить статус системы\n\n",
        "Чтобы задать вопрос к своей базе знаний, просто напиши его в чат."
    )

    await message.answer(**help_text.as_kwargs())

# Команда /status
@router.message(Command("status"))
async def cmd_status(message: Message):
    """Обработчик команды /status - показывает текущее состояние системы"""
    user_id = message.from_user.id

    if user_id not in user_data:
        user_data[user_id] = {
            "documents": []
        }

    # Статус системы
    status_text = Text(
        "📊 ", Bold("СТАТУС СИСТЕМЫ"), "\n\n",
        f"База знаний загружена: {'✅ Да' if rag_system.is_loaded else '❌ Нет'}\n"
    )

    # Если у нас есть информация о загруженных документах, добавляем ее
    documents = user_data[user_id].get("documents", [])
    if documents:
        status_text += Text("📚 ", Bold("ПОСЛЕДНИЕ ЗАПРОСЫ"), ":\n")
        for i, doc in enumerate(documents[-5:], 1):
            status_text += Text(f"{i}. {doc}\n")
    else:
        status_text += Text("❓ Еще не было запросов. Задайте вопрос!")

    await message.answer(**status_text.as_kwargs())

# Обработчик текстовых сообщений (вопросов)
@router.message(F.text)
async def handle_message(message: Message):
    """Обработчик текстовых сообщений (вопросов)"""
    user_id = message.from_user.id

    # Проверяем, инициализированы ли данные пользователя
    if user_id not in user_data:
        user_data[user_id] = {
            "documents": []
        }

    # Проверяем, загружены ли документы
    if not rag_system.is_loaded:
        await message.answer(
            "⚠️ База знаний не загружена! Для начала работы с ботом необходимо "
            "загрузить документы в Colab-ноутбуке и запустить бота оттуда."
        )
        return

    # Получаем вопрос
    question = message.text

    # Сохраняем вопрос в истории
    user_data[user_id]["documents"].append(question)

    # Сообщаем о начале обработки
    processing_msg = await message.answer("🧠 Обрабатываю вопрос... Секунду...")

    try:
        # Получаем ответ на вопрос
        answer = await rag_system.query(question)

        # Отправляем ответ
        await message.answer(answer)
    except Exception as e:
        # В случае ошибки
        await message.answer(f"❌ Ошибка при обработке вопроса: {str(e)}")
    finally:
        # Удаляем сообщение о загрузке
        try:
            await bot.delete_message(chat_id=message.chat.id, message_id=processing_msg.message_id)
        except aiogram.exceptions.TelegramBadRequest:
            # Если сообщение уже удалено или прошло слишком много времени
            pass

# Функция запуска бота
async def start_bot():
    """Запуск бота"""
    # Регистрируем роутер
    dp.include_router(router)

    # Пропускаем накопившиеся обновления и запускаем бота
    await bot.delete_webhook(drop_pending_updates=True)

    logger.info("🚀 Бот запущен! VIBE CODING RAG-BOT В ДЕЛЕ!")

    # Запускаем бота
    await dp.start_polling(bot, allowed_updates=dp.resolve_used_update_types())

# %%
# @title 🤖 Запуск Telegram-бота
# @markdown Нажмите кнопку для запуска Telegram-бота:

# Функция для запуска всего процесса
async def run_full_system():
    """Запуск полной системы: загрузка документов и запуск бота"""
    # Проверяем, загружена ли уже RAG-система
    if not rag_system.is_loaded:
        # Пробуем загрузить существующее векторное хранилище
        await load_vectorstore()

        # Если не удалось загрузить, то загружаем документы с нуля
        if not rag_system.is_loaded:
            await load_docs_from_drive()

    # Запускаем бота
    if rag_system.is_loaded:
        await start_bot()
    else:
        logger.error("❌ Не удалось загрузить RAG-систему! Бот не запущен.")
        if IN_COLAB:
            from IPython.display import HTML, display
            display(HTML("""
            <div style="background-color:#f8d7da; padding:20px; border-radius:5px; color:#721c24">
                <h3 style="margin-top:0">❌ Ошибка! RAG-система не загружена!</h3>
                <p>Проверьте путь к документам и повторите попытку.</p>
            </div>
            """))

# Запускаем полную систему при выполнении этой ячейки
if __name__ == "__main__":
    try:
        # Запускаем полную систему
        asyncio.run(run_full_system())
    except (KeyboardInterrupt, SystemExit):
        # Корректное завершение
        logger.info("👋 Система остановлена!")
# Out:
# WARNING:aiogram.dispatcher:Received SIGINT signal
